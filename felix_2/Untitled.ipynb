# %%
import pandas as pd
import pickle

# %%
with open("results.pkl", 'rb') as file:
    runs = pickle.load(file)

# %%
runs[0]
# Out:
# {'block_target_counter': {'FACE': 1, 'HOUSE': 1, 'UNCLEAR': 1},
#  'blocks': [{'target': 'FACE',
#    'time': (1530711125.8193731, 1530711132.2592595),
#    'trial_data': {'RT': [0.674666166305542,
#      0.4713327884674072,
#      0.43700337409973145,
#      0.4347963333129883,
#      0.4244265556335449],
#     'decision': ['LEFT', 'RIGHT', 'RIGHT', 'LEFT', 'LEFT'],
#     'decision_onset': [1530711128.4992607,
#      1530711129.2992785,
#      1530711130.2672513,
#      1530711131.2672598,
#      1530711132.2592375],
#     'face_id': ['f10', 'f4', 'f0', 'f10', 'f0'],
#     'face_orientation': ['LEFT', 'RIGHT', 'RIGHT', 'LEFT', 'LEFT'],
#     'follwing ITI': [0.325333833694458,
#      0.5286672115325928,
#      0.5629966259002686,
#      0.5652036666870117,
#      0],
#     'house_id': ['h6', 'h7', 'h3', 'h2', 'h0'],
#     'house_orientation': ['RIGHT', 'LEFT', 'RIGHT', 'RIGHT', 'LEFT'],
#     'presentations_onset': [1530711127.8245945,
#      1530711128.8279457,
# ...

# %%
pd.DataFrame(runs[0]["blocks"][1]["trial_data"])
# Out:
#          RT decision  decision_onset face_id face_orientation  follwing ITI  \
# 0  0.681995     LEFT    1.530711e+09      f3            RIGHT      0.318005
# 1  0.559862    RIGHT    1.530711e+09      f4            RIGHT      0.440138
# 2  0.421760     LEFT    1.530711e+09     f10             LEFT      0.578240
# 3       NaN     None             NaN      f2            RIGHT      0.200000
# 4  0.620544    RIGHT    1.530711e+09      f4             LEFT      0.000000
#
#   house_id house_orientation  presentations_onset  was_congruent
# 0       h7              LEFT         1.530711e+09          False
# 1       h3             RIGHT         1.530711e+09           True
# 2       h8              LEFT         1.530711e+09           True
# 3      h10              LEFT         1.530711e+09          False
# 4       h8             RIGHT         1.530711e+09          False
